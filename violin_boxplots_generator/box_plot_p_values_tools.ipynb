# %% [markdown]
# ## Create Violin plots and P-value for the Paper
#
# - Reads the data.
# - Generate a datFrame.
# - Plots the data.
# - Generates P-Value.

# %%
import pandas as pd
import scipy.stats as stats
from scipy.stats import ttest_1samp
import numpy as np
# %matplotlib inline

# %% [markdown]
# Read the csv file for lamin expression "lamin_ex_p_value.csv" and store the data in df.

# %%
colors_all = "Accent,Blues,Blues_r,BrBG,BrBG_r,BuGn,BuGn_r,BuPu,BuPu_r,CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r"
colors_all = colors_all.replace(" ", "")
#colors_all ="YlGn,YlGnBu,YlGnBu_r,YlGn_r,YlOrBr,YlOrBr_r,YlOrRd,YlOrRd_r"
#list_color = list(colors_all.split(","))
list_color = ['hot_r'];#, 'gist_heat_r', 'afmhot_r']
print(list_color)
# Out:
# ['hot_r']

# %% [markdown]
# Just vsualize the data

# %%
def plot_violin(infile,n_color):
    import seaborn as sns
    import matplotlib.pyplot as plt
    df = pd.read_csv(infile)
    for mapc in list_color:
        ax = sns.violinplot(x="variable", y="value", data=pd.melt(df), palette=sns.color_palette(mapc, n_colors=n_color))
        y_axis = "Nuc/Cyto YR"
        x_axis = "Substrate Young's Modulus (kPa)"
        ax.set_xlabel(x_axis,fontsize=12)
        ax.set_ylabel(y_axis,fontsize=12)
        ax.set_ylim(0.5,2.9)
        fig = ax.get_figure()
        fig.savefig("boxplot"+mapc+".pdf")
        plt.show()
        plt.close()

# %%
def plot_boxplots(infile):
    import seaborn as sns
    import matplotlib.pyplot as plt
    parm_2 = 'PDMS'
    parm_1 = 'PAA'
    my_pal = {parm_2: "#FF0000", parm_1:"#180AD4"}
    df = pd.read_csv(infile, header=[0, 1])
    #print(dfn.head(200))
    #dfn.sort_values(by=['variable_1'], inplace=True)
    #columns = [parm_1, parm_3, parm_2]
    #df = df[columns]
    order = ["0.3", "1","2","5","12","18","21","30","50"]
    #ax = sns.scatterplot(x="variable_1", y="value", hue="variable_0", data=pd.melt(df), palette=my_pal)
    #ax = sns.swarmplot(x="variable_1", y="value", hue="variable_0", data=pd.melt(df), palette=my_pal, order=order)
    ax = sns.boxplot(x="variable_1", y="value", hue="variable_0", data=pd.melt(df), palette=my_pal, order=order)
    y_axis = "Nuc/Cyto YR"
    x_axis = "Substrate Young's Modulus (kPa)"
    ax.set(xlabel=x_axis, ylabel=y_axis)
    ax.set_ylim(0.5,2.9)
    ax.legend(title=False, fontsize=12)
    ax.set_xlabel(x_axis,fontsize=12)
    ax.set_ylabel(y_axis,fontsize=12)
    fig = ax.get_figure()
    fig.savefig("boxplot_pdms_paa.pdf")
    plt.show()
    plt.close()

# %%
def plot_boxplots_1(infile):
    import seaborn as sns
    import matplotlib.pyplot as plt
    parm_2 = 'Endogenous YAP'
    parm_1 = 'Exogenous YAP'
    my_pal = {parm_2: "#FF0000", parm_1:"#00FF00"}
    df = pd.read_csv(infile, header=[0, 1])
    #print(dfn.head(200))
    #dfn.sort_values(by=['variable_1'], inplace=True)
    #columns = [parm_1, parm_3, parm_2]
    #df = df[columns]
    order = ["0.3", "glass"]
    #ax = sns.scatterplot(x="variable_1", y="value", hue="variable_0", data=pd.melt(df), palette=my_pal)
    #ax = sns.swarmplot(x="variable_1", y="value", hue="variable_0", data=pd.melt(df), palette=my_pal, order=order)
    ax = sns.boxplot(x="variable_1", y="value", hue="variable_0", data=pd.melt(df), palette=my_pal, order=order, width = 0.4)
    y_axis = "Nuc/Cyto YR"
    x_axis = "Substrate Young's Modulus (kPa)"
    ax.set(xlabel=x_axis, ylabel=y_axis)
    ax.set_ylim(0.5,2.9)
    ax.legend(title=False, fontsize=12)
    ax.set_xlabel(x_axis,fontsize=12)
    ax.set_ylabel(y_axis,fontsize=12)
    fig = ax.get_figure()
    fig.savefig("end_exd_yap.pdf")
    plt.show()
    plt.close()

# %% [markdown]
# ## Plot for the first data

# %%
infile = "paper_1_box_plot_1.csv"
plot_violin(infile,7)

# %% [markdown]
# ## Plot PDMS and PAA Violin plots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
infile = "plot_pdms_pa.csv"
df = pd.read_csv(infile, header=[0, 1])
order = ["0.3", "1","2","5","12","18","21","30","50"]
parm_2 = 'PDMS'
parm_1 = 'PAA'
my_pal = {parm_2: "#FF0000", parm_1:"#180AD4"}
ax = sns.violinplot(x="variable_1", y="value", hue="variable_0", data=pd.melt(df), palette=my_pal, order=order, width=0.9)
y_axis = "Nuc/Cyto YR"
x_axis = "Substrate Young's Modulus (kPa)"
ax.set(xlabel=x_axis, ylabel=y_axis)
ax.set_ylim(0.18,3.2)
ax.legend(title=False, fontsize=12)
ax.set_xlabel(x_axis,fontsize=12)
ax.set_ylabel(y_axis,fontsize=12)
fig = ax.get_figure()
fig.savefig("boxplot_pdms_paa_violin.pdf")
plt.show()
plt.close()

# %% [markdown]
# ## Compute P-Value and T-Value of the plots

# %%
import itertools
alpha = 0.05 
paired_list = df.columns
paired = itertools.combinations(paired_list, 2)
#print(paired)
#print(paired)
for var in paired:
    parm1 = var[0]
    parm2 = var[1]
    print(var)
    x = df[parm1].dropna()
    y = df[parm2].dropna()
    
    ttest1,pval1 = stats.ttest_ind(x, y)
    print("this is P-value between {} and {}: {}".format(parm1, parm2, pval1))
    print("this is T-value between {} and {}: {}".format(parm1, parm2, ttest1))
# Out:
# (('PDMS', '0.3'), ('PAA', '1'))
# this is P-value between ('PDMS', '0.3') and ('PAA', '1'): 4.832110131587619e-12
# this is T-value between ('PDMS', '0.3') and ('PAA', '1'): 8.08084193880024
# (('PDMS', '0.3'), ('PDMS', '2'))
# this is P-value between ('PDMS', '0.3') and ('PDMS', '2'): 0.5746779730799909
# this is T-value between ('PDMS', '0.3') and ('PDMS', '2'): -0.5646086355946626
# (('PDMS', '0.3'), ('PDMS', '5'))
# this is P-value between ('PDMS', '0.3') and ('PDMS', '5'): 0.9836454285698484
# this is T-value between ('PDMS', '0.3') and ('PDMS', '5'): -0.020597676403121365
# (('PDMS', '0.3'), ('PAA', '5'))
# this is P-value between ('PDMS', '0.3') and ('PAA', '5'): 0.32347366634801966
# this is T-value between ('PDMS', '0.3') and ('PAA', '5'): 0.99332524242321
# (('PDMS', '0.3'), ('PDMS', '12'))
# this is P-value between ('PDMS', '0.3') and ('PDMS', '12'): 0.7119936344634133
# this is T-value between ('PDMS', '0.3') and ('PDMS', '12'): -0.3716296561683822
# (('PDMS', '0.3'), ('PDMS', '18'))
# this is P-value between ('PDMS', '0.3') and ('PDMS', '18'): 0.874115221336697
# this is T-value between ('PDMS', '0.3') and ('PDMS', '18'): -0.15916029937806236
# (('PDMS', '0.3'), ('PAA', '21'))
# this is P-value between ('PDMS', '0.3') and ('PAA', '21'): 0.6593480917257872
# this is T-value between ('PDMS', '0.3') and ('PAA', '21'): 0.44248405454805884
# (('PDMS', '0.3'), ('PAA', '30'))
# this is P-value between ('PDMS', '0.3') and ('PAA', '30'): 0.8589211108690895
# this is T-value between ('PDMS', '0.3') and ('PAA', '30'): 0.1789912724731921
# (('PDMS', '0.3'), ('PDMS', '50'))
# this is P-value between ('PDMS', '0.3') and ('PDMS', '50'): 0.2997221988019411
# this is T-value between ('PDMS', '0.3') and ('PDMS', '50'): 1.0442536757972478
# (('PDMS', '0.3'), ('PAA', '50'))
# this is P-value between ('PDMS', '0.3') and ('PAA', '50'): 0.8795310584351135
# this is T-value between ('PDMS', '0.3') and ('PAA', '50'): 0.1520204521141709
# (('PAA', '1'), ('PDMS', '2'))
# this is P-value between ('PAA', '1') and ('PDMS', '2'): 2.059737433461888e-21
# this is T-value between ('PAA', '1') and ('PDMS', '2'): -12.517476270386704
# (('PAA', '1'), ('PDMS', '5'))
# this is P-value between ('PAA', '1') and ('PDMS', '5'): 3.965008070902255e-16
# this is T-value between ('PAA', '1') and ('PDMS', '5'): -9.979266036063699
# (('PAA', '1'), ('PAA', '5'))
# this is P-value between ('PAA', '1') and ('PAA', '5'): 1.0378636989363593e-22
# this is T-value between ('PAA', '1') and ('PAA', '5'): -12.227614381824587
# (('PAA', '1'), ('PDMS', '12'))
# this is P-value between ('PAA', '1') and ('PDMS', '12'): 7.421970818596894e-13
# this is T-value between ('PAA', '1') and ('PDMS', '12'): -8.548260684016547
# (('PAA', '1'), ('PDMS', '18'))
# this is P-value between ('PAA', '1') and ('PDMS', '18'): 8.164407309839735e-16
# this is T-value between ('PAA', '1') and ('PDMS', '18'): -9.736887378267886
# (('PAA', '1'), ('PAA', '21'))
# this is P-value between ('PAA', '1') and ('PAA', '21'): 1.911048810449494e-24
# this is T-value between ('PAA', '1') and ('PAA', '21'): -13.053917658898083
# (('PAA', '1'), ('PAA', '30'))
# this is P-value between ('PAA', '1') and ('PAA', '30'): 3.8852032211168625e-15
# this is T-value between ('PAA', '1') and ('PAA', '30'): -9.901100156589301
# (('PAA', '1'), ('PDMS', '50'))
# this is P-value between ('PAA', '1') and ('PDMS', '50'): 1.0197965683080583e-14
# this is T-value between ('PAA', '1') and ('PDMS', '50'): -8.931861707853058
# (('PAA', '1'), ('PAA', '50'))
# this is P-value between ('PAA', '1') and ('PAA', '50'): 4.6005618428109955e-17
# this is T-value between ('PAA', '1') and ('PAA', '50'): -9.807259713077574
# (('PDMS', '2'), ('PDMS', '5'))
# this is P-value between ('PDMS', '2') and ('PDMS', '5'): 0.5188815881013185
# this is T-value between ('PDMS', '2') and ('PDMS', '5'): 0.6488961977893888
# (('PDMS', '2'), ('PAA', '5'))
# this is P-value between ('PDMS', '2') and ('PAA', '5'): 0.025949828220222723
# this is T-value between ('PDMS', '2') and ('PAA', '5'): 2.264421677040153
# (('PDMS', '2'), ('PDMS', '12'))
# this is P-value between ('PDMS', '2') and ('PDMS', '12'): 0.9523835008324875
# this is T-value between ('PDMS', '2') and ('PDMS', '12'): 0.06000837252324063
# (('PDMS', '2'), ('PDMS', '18'))
# this is P-value between ('PDMS', '2') and ('PDMS', '18'): 0.6474006736092375
# this is T-value between ('PDMS', '2') and ('PDMS', '18'): 0.45954415632532875
# (('PDMS', '2'), ('PAA', '21'))
# this is P-value between ('PDMS', '2') and ('PAA', '21'): 0.1311762744468442
# this is T-value between ('PDMS', '2') and ('PAA', '21'): 1.5238372963272213
# (('PDMS', '2'), ('PAA', '30'))
# this is P-value between ('PDMS', '2') and ('PAA', '30'): 0.4022677955294762
# this is T-value between ('PDMS', '2') and ('PAA', '30'): 0.8455675950996585
# (('PDMS', '2'), ('PDMS', '50'))
# this is P-value between ('PDMS', '2') and ('PDMS', '50'): 0.03780710497252715
# this is T-value between ('PDMS', '2') and ('PDMS', '50'): 2.110706049459094
# (('PDMS', '2'), ('PAA', '50'))
# this is P-value between ('PDMS', '2') and ('PAA', '50'): 0.34943417688847755
# this is T-value between ('PDMS', '2') and ('PAA', '50'): 0.9404283536890007
# (('PDMS', '5'), ('PAA', '5'))
# this is P-value between ('PDMS', '5') and ('PAA', '5'): 0.22689743066996518
# this is T-value between ('PDMS', '5') and ('PAA', '5'): 1.2168957774793243
# (('PDMS', '5'), ('PDMS', '12'))
# this is P-value between ('PDMS', '5') and ('PDMS', '12'): 0.6758243832506656
# this is T-value between ('PDMS', '5') and ('PDMS', '12'): -0.4206851464915288
# (('PDMS', '5'), ('PDMS', '18'))
# this is P-value between ('PDMS', '5') and ('PDMS', '18'): 0.8706471680890282
# this is T-value between ('PDMS', '5') and ('PDMS', '18'): -0.16351199665894106
# (('PDMS', '5'), ('PAA', '21'))
# this is P-value between ('PDMS', '5') and ('PAA', '21'): 0.5764421389045555
# this is T-value between ('PDMS', '5') and ('PAA', '21'): 0.5607515042106704
# (('PDMS', '5'), ('PAA', '30'))
# this is P-value between ('PDMS', '5') and ('PAA', '30'): 0.81129806595795
# this is T-value between ('PDMS', '5') and ('PAA', '30'): 0.2402241661830255
# (('PDMS', '5'), ('PDMS', '50'))
# this is P-value between ('PDMS', '5') and ('PDMS', '50'): 0.2132347392974052
# this is T-value between ('PDMS', '5') and ('PDMS', '50'): 1.2545927453137262
# (('PDMS', '5'), ('PAA', '50'))
# this is P-value between ('PDMS', '5') and ('PAA', '50'): 0.8384790708270814
# this is T-value between ('PDMS', '5') and ('PAA', '50'): 0.20442351060174382
# (('PAA', '5'), ('PDMS', '12'))
# this is P-value between ('PAA', '5') and ('PDMS', '12'): 0.11797017435697879
# this is T-value between ('PAA', '5') and ('PDMS', '12'): -1.58057869626021
# (('PAA', '5'), ('PDMS', '18'))
# this is P-value between ('PAA', '5') and ('PDMS', '18'): 0.1546230977910246
# this is T-value between ('PAA', '5') and ('PDMS', '18'): -1.4351931320467999
# (('PAA', '5'), ('PAA', '21'))
# this is P-value between ('PAA', '5') and ('PAA', '21'): 0.371224256395574
# this is T-value between ('PAA', '5') and ('PAA', '21'): -0.8976940126183486
# (('PAA', '5'), ('PAA', '30'))
# this is P-value between ('PAA', '5') and ('PAA', '30'): 0.4806230255690084
# this is T-value between ('PAA', '5') and ('PAA', '30'): -0.708934627045645
# (('PAA', '5'), ('PDMS', '50'))
# this is P-value between ('PAA', '5') and ('PDMS', '50'): 0.7165321759531118
# this is T-value between ('PAA', '5') and ('PDMS', '50'): 0.3640245242423472
# (('PAA', '5'), ('PAA', '50'))
# this is P-value between ('PAA', '5') and ('PAA', '50'): 0.28152898922461006
# this is T-value between ('PAA', '5') and ('PAA', '50'): -1.0817179457353392
# (('PDMS', '12'), ('PDMS', '18'))
# this is P-value between ('PDMS', '12') and ('PDMS', '18'): 0.775353158311418
# this is T-value between ('PDMS', '12') and ('PDMS', '18'): 0.28684011408797605
# (('PDMS', '12'), ('PAA', '21'))
# this is P-value between ('PDMS', '12') and ('PAA', '21'): 0.30183848233721755
# this is T-value between ('PDMS', '12') and ('PAA', '21'): 1.039564058931424
# (('PDMS', '12'), ('PAA', '30'))
# this is P-value between ('PDMS', '12') and ('PAA', '30'): 0.5912860981687094
# this is T-value between ('PDMS', '12') and ('PAA', '30'): 0.542098580972341
# (('PDMS', '12'), ('PDMS', '50'))
# this is P-value between ('PDMS', '12') and ('PDMS', '50'): 0.13359472945337647
# this is T-value between ('PDMS', '12') and ('PDMS', '50'): 1.5172005745638273
# (('PDMS', '12'), ('PAA', '50'))
# this is P-value between ('PDMS', '12') and ('PAA', '50'): 0.5150522044870904
# this is T-value between ('PDMS', '12') and ('PAA', '50'): 0.6538277355167397
# (('PDMS', '18'), ('PAA', '21'))
# this is P-value between ('PDMS', '18') and ('PAA', '21'): 0.4362852926801296
# this is T-value between ('PDMS', '18') and ('PAA', '21'): 0.7820082297726545
# (('PDMS', '18'), ('PAA', '30'))
# this is P-value between ('PDMS', '18') and ('PAA', '30'): 0.7159620845589922
# this is T-value between ('PDMS', '18') and ('PAA', '30'): 0.3660611180857595
# (('PDMS', '18'), ('PDMS', '50'))
# this is P-value between ('PDMS', '18') and ('PDMS', '50'): 0.14932480824350217
# this is T-value between ('PDMS', '18') and ('PDMS', '50'): 1.4551000334163444
# (('PDMS', '18'), ('PAA', '50'))
# this is P-value between ('PDMS', '18') and ('PAA', '50'): 0.6908145510354633
# this is T-value between ('PDMS', '18') and ('PAA', '50'): 0.3989647870143944
# (('PAA', '21'), ('PAA', '30'))
# this is P-value between ('PAA', '21') and ('PAA', '30'): 0.8833726360894452
# this is T-value between ('PAA', '21') and ('PAA', '30'): -0.14723137662771155
# (('PAA', '21'), ('PDMS', '50'))
# this is P-value between ('PAA', '21') and ('PDMS', '50'): 0.2777634206171945
# this is T-value between ('PAA', '21') and ('PDMS', '50'): 1.0908573312597127
# (('PAA', '21'), ('PAA', '50'))
# this is P-value between ('PAA', '21') and ('PAA', '50'): 0.7280165833532917
# this is T-value between ('PAA', '21') and ('PAA', '50'): -0.34859231879205893
# (('PAA', '30'), ('PDMS', '50'))
# this is P-value between ('PAA', '30') and ('PDMS', '50'): 0.45066988746940684
# this is T-value between ('PAA', '30') and ('PDMS', '50'): 0.7588062912422131
# (('PAA', '30'), ('PAA', '50'))
# this is P-value between ('PAA', '30') and ('PAA', '50'): 0.9290320364727327
# this is T-value between ('PAA', '30') and ('PAA', '50'): -0.08935854346559512
# (('PDMS', '50'), ('PAA', '50'))
# this is P-value between ('PDMS', '50') and ('PAA', '50'): 0.2192677939183724
# this is T-value between ('PDMS', '50') and ('PAA', '50'): -1.2352752624667958

# %% [markdown]
# ## Plot box-plot and violin-plot Endogenous and Exogenous YAP

# %%
infile = "end_exd_yap_v2.csv"
import seaborn as sns
import matplotlib.pyplot as plt
parm_2 = 'Endogenous YAP'
parm_1 = 'Exogenous YAP'
my_pal = {parm_2: "#FF0000", parm_1:"#00FF00"}
df = pd.read_csv(infile, header=[0, 1])
order = ["0.3 kPa (PDMS)", "48 kPa (PDMS)", "75 GPa (glass)"]
ax = sns.boxplot(x="variable_1", y="value", hue="variable_0", data=pd.melt(df), palette=my_pal, order=order, width = 0.4)
y_axis = "Nuc/Cyto YR"
x_axis = "Substrate Young's Modulus (kPa)"
ax.set(xlabel=x_axis, ylabel=y_axis)
ax.set_ylim(0.2,3.2)
ax.legend(title=False, fontsize=12)
ax.set_xlabel(x_axis,fontsize=12)
ax.set_ylabel(y_axis,fontsize=12)
fig = ax.get_figure()
fig.savefig("end_exd_yap_box_plot.pdf")
plt.show()
plt.close()



ax = sns.violinplot(x="variable_1", y="value", hue="variable_0", data=pd.melt(df), palette=my_pal, order=order, width = 0.6)
y_axis = "Nuc/Cyto YR"
x_axis = "Substrate Young's Modulus (kPa)"
ax.set(xlabel=x_axis, ylabel=y_axis)
ax.set_ylim(0.25,3.2)
ax.legend(title=False, fontsize=12)
ax.set_xlabel(x_axis,fontsize=12)
ax.set_ylabel(y_axis,fontsize=12)
fig = ax.get_figure()
fig.savefig("end_exd_yap_violin_plot.pdf")
plt.show()
plt.close()

# %% [markdown]
# ## Plot LamA/C siRNA and WT

# %%
infile = "lamin_ex_p_value.csv"
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(infile)

df = df[["LamA/C siRNA","WT"]]
order = ["LamA/C siRNA","WT"]
ax = sns.violinplot(x="variable", y="value",  data=pd.melt(df),  order=order, width = 0.4)
y_axis = "Nuc/Cyto YR"
x_axis = "Substrate Young's Modulus (kPa)"
ax.set(xlabel=x_axis, ylabel=y_axis)
ax.set_xlabel(x_axis,fontsize=12)
ax.set_ylabel(y_axis,fontsize=12)
fig = ax.get_figure()
fig.savefig("LamA_WT.pdf")
plt.show()
plt.close()

# %%
def plot_boxplots_3(infile):
    import seaborn as sns
    import matplotlib.pyplot as plt

    df = pd.read_csv(infile)
    order = ['1', '5', '20', '50']
    
    ax = sns.boxplot(x="variable", y="value", data=pd.melt(df), palette=sns.color_palette('Blues'), order=order, width = 0.5)
    y_axis = "Nuc/Cyto YR"
    x_axis = "Substrate Young's Modulus (kPa)"
    ax.set(xlabel=x_axis, ylabel=y_axis)
    ax.set_ylim(0.5,2.9)
    #ax.legend(title=False, fontsize=12)
    ax.set_xlabel(x_axis,fontsize=12)
    ax.set_ylabel(y_axis,fontsize=12)
    fig = ax.get_figure()
    fig.savefig("paa_yap.pdf")
    plt.show()
    plt.close()

# %%
def plot_violin_2(infile):
    import seaborn as sns
    import matplotlib.pyplot as plt
    df = pd.read_csv(infile)
    ax = sns.violinplot(x="variable", y="value", data=pd.melt(df), palette=sns.color_palette('Blues'))
    y_axis = "Nuc/Cyto YR"
    x_axis = "Substrate Young's Modulus (kPa)"
    ax.set_xlabel(x_axis,fontsize=12)
    ax.set_ylabel(y_axis,fontsize=12)
    ax.set_ylim(0.5,2.9)
    fig = ax.get_figure()
    fig.savefig("violinplot_paa.pdf")
    plt.show()
    plt.close()

# %%
infile = "yap_paa.csv"
df = pd.read_csv(infile)
plot_boxplots_3(infile)
plot_violin_2(infile)

# %%
import itertools
alpha = 0.05 
paired_list = df.columns
paired = itertools.combinations(paired_list, 2)
#print(paired)
#print(paired)
for var in paired:
    parm1 = var[0]
    parm2 = var[1]
    print(var)
    x = df[parm1].dropna()
    y = df[parm2].dropna()
    
    ttest1,pval1 = stats.ttest_ind(x, y)
    print("this is P-value between {} and {}: {}".format(parm1, parm2, pval1))
    print("this is T-value between {} and {}: {}".format(parm1, parm2, ttest1))
# Out:
# ('1', '5')
# this is P-value between 1 and 5: 1.0378636989363593e-22
# this is T-value between 1 and 5: -12.227614381824587
# ('1', '20')
# this is P-value between 1 and 20: 1.3350800708502428e-25
# this is T-value between 1 and 20: -14.054294001367895
# ('1', '50')
# this is P-value between 1 and 50: 4.6005618428109955e-17
# this is T-value between 1 and 50: -9.807259713077574
# ('5', '20')
# this is P-value between 5 and 20: 0.06602091653043948
# this is T-value between 5 and 20: -1.8582247040098225
# ('5', '50')
# this is P-value between 5 and 50: 0.28152898922461006
# this is T-value between 5 and 50: -1.0817179457353392
# ('20', '50')
# this is P-value between 20 and 50: 0.643273337219315
# this is T-value between 20 and 50: 0.4644690990075678
